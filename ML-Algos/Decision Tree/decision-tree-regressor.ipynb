# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.tree import DecisionTreeRegressor 
from pandas_datareader import data
from sklearn.model_selection import train_test_split as tts 
from sklearn import metrics 
from sklearn.metrics import r2_score 
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('boston_house_prices.csv')

# %%
df.head()
# Out:
#        506  13 Unnamed: 2  ... Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0     CRIM  ZN      INDUS  ...           B       LSTAT        MEDV
# 1  0.00632  18       2.31  ...       396.9        4.98          24
# 2  0.02731   0       7.07  ...       396.9        9.14        21.6
# 3  0.02729   0       7.07  ...      392.83        4.03        34.7
# 4  0.03237   0       2.18  ...      394.63        2.94        33.4
#
# [5 rows x 14 columns]

# %%
df = pd.DataFrame

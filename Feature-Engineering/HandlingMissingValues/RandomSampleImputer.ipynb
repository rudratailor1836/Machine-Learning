# %%
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split as tts 

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('train_titanic.csv', usecols=['Age', 'Fare', 'Survived'])

df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train, X_test, y_train, y_test = tts(X,y,test_size=0.2, random_state=2)

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']

# %%
X_train.head()
# Out:
#       Age     Fare  Age_imputed
# 30   40.0  27.7208         40.0
# 10    4.0  16.7000          4.0
# 873  47.0   9.0000         47.0
# 182   9.0  31.3875          9.0
# 876  20.0   9.8458         20.0

# %%
X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\1280327713.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         19.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         35.0
# 168   NaN   25.9250         50.0
#
# [712 rows x 3 columns]

# %%
sns.distplot(X_train['Age'], label='Original')
sns.distplot(X_train['Age_imputed'], label='Imputed')

plt.legend()
plt.show()
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\4059798820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'], label='Original')
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\4059798820.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
X_train['Age'].var(), X_train['Age_imputed'].var()
# Out:
# (np.float64(204.34951339046142), np.float64(204.71588819493832))

# %%
X_train[['Fare', 'Age', 'Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    63.537026
# Age            71.512440  204.349513   204.349513
# Age_imputed    63.537026  204.349513   204.715888

# %%
X_train[['Age', 'Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
sampled_val  = X_train['Age'].dropna().sample(1,random_state=int(observation['Fare']))
# While making depoyable project

# %%
data = pd.read_csv('house-train.csv', usecols=['GarageQual', 'FireplaceQu', 'SalePrice'])

# %%
data.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
data.isnull().mean()
# Out:
# FireplaceQu    0.472603
# GarageQual     0.055479
# SalePrice      0.000000
# dtype: float64

# %%
X = data 
y = data['SalePrice']

# %%
X_train, X_test,y_train,y_test = tts(X,y,random_state=2, test_size=0.2)

# %%
X_train['GQUal_imputed'] = X_train['GarageQual']
X_test['GQUal_imputed'] = X_test['GarageQual']

X_train['FQu_imputed'] = X_train['FireplaceQu']
X_test['FQu_imputed'] = X_test['FireplaceQu']

# %%
X_train['GQUal_imputed'][X_train['GQUal_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
X_test['GQUal_imputed'][X_test['GQUal_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values

X_train['FQu_imputed'][X_train['FQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_train['FireplaceQu'].isnull().sum()).values
X_test['FQu_imputed'][X_test['FQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_test['FireplaceQu'].isnull().sum()).values
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\384836230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['GQUal_imputed'][X_train['GQUal_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\384836230.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...

# %%
temp = pd.concat(
    [
        X_train['GarageQual'].value_counts() / len(X_train['GarageQual'].dropna()),
        X_train['GQUal_imputed'].value_counts() / len(X_train)
    ],
    axis=1
)
temp.columns = ['Original', 'Imputed']

# %%
temp
# Out:
#     Original   Imputed
# TA  0.951043  0.952055
# Fa  0.037171  0.035959
# Gd  0.009973  0.010274
# Po  0.000907  0.000856
# Ex  0.000907  0.000856

# %%
temp = pd.concat(
    [
        X_train['FireplaceQu'].value_counts() / len(X_train['FireplaceQu'].dropna()),
        X_train['FQu_imputed'].value_counts() / len(data)
    ],
    axis=1
)
temp.columns = ['Original', 'Imputed']

# %%
temp
# Out:
#     Original   Imputed
# Gd  0.494272  0.391781
# TA  0.412439  0.331507
# Fa  0.040917  0.032877
# Po  0.027823  0.023288
# Ex  0.024550  0.020548

# %%
for category in X_train['FireplaceQu'].dropna().unique():
    sns.distplot(X_train[X_train['FireplaceQu']== category]['SalePrice'],hist=False, label=category)
plt.show()
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\4162392483.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[X_train['FireplaceQu']== category]['SalePrice'],hist=False, label=category)
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\4162392483.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for category in X_train['FQu_imputed'].dropna().unique():
    sns.distplot(X_train[X_train['FQu_imputed']== category]['SalePrice'],hist=False, label=category)
plt.show()
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\2173024404.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[X_train['FQu_imputed']== category]['SalePrice'],hist=False, label=category)
# C:\Users\rudra\AppData\Local\Temp\ipykernel_6172\2173024404.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
